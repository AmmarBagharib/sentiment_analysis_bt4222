# %%
import pandas as pd 
import numpy as np
import re

##LDA stuff
import gensim
from gensim.utils import simple_preprocess
import nltk
from nltk.corpus import words
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

##cleaning stuff
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

import gensim.corpora as corpora

# %%
df = pd.read_csv('../data/cleaned/cleaned_ibis-sg-bencoolen.csv')
df.head()
# Out:
#    Unnamed: 0                date_of_stay traveller_username  \
# 0           0   Date of stay: August 2023   Love_Life_Sydney
# 1           1   Date of stay: August 2023            Bilal S
# 2           2  Date of stay: October 2022   Anthony Fernando
# 3           3   Date of stay: August 2023            Mjkc204
# 4           4   Date of stay: August 2022         Aung Nanda
#
#                       review_title  \
# 0            Clean and comfortable
# 1      Good hotel, great location
# 2   Good place for a decent price.
# 3  Great Location and great staff.
# 4            Good for budget stay.
#
#                                          review_text  \
# 0  Hotel rooms in Singapore are so expensive so t...
# 1  This is a great place! Location is great but t...
# 2  Good place good price  Easy access to the city...
# 3  The IBIS was a neat and tidy hotel in line wit...
# 4  I stayed there for 7 days. It was a nice locat...
#
#                          travel_type     traveller_country_origin  \
# 0   Trip type: Travelled as a couple            Sydney, Australia
# 1   Trip type: Travelled with family               Houston, Texas
# 2  Trip type: Travelled with friends  Dubai, United Arab Emirates
# 3          Trip type: Travelled solo        Ellenbrook, Australia
# 4   Trip type: Travelled on business  Dubai, United Arab Emirates
#
#    traveller_total_contributions  traveller_total_helpful_contributions  \
# 0                         2302.0                                  871.0
# 1                            4.0                                    NaN
# 2                           39.0                                   38.0
# 3                           37.0                                   19.0
# 4                            3.0                                    4.0
#
#    rating1  rating2  rating  valid_rating     label  \
# 0      NaN      4.0     4.0          True  Positive
# 1      5.0      NaN     5.0          True  Positive
# 2      5.0      NaN     5.0          True  Positive
# 3      5.0      NaN     5.0          True  Positive
# 4      NaN      4.0     4.0          True  Positive
#
#                                       cleaned_review  \
# 0  clean comfortable hotel room singapore expensi...
# 1  good hotel great location great place location...
# 2  good place decent price good place good price ...
# 3  great location great staff ibis neat tidy hote...
# 4  good budget stay I stay day nice location seve...
#
#                                      combined_review        date      covid
# 0  Clean and comfortable Hotel rooms in Singapore...  2023-08-01  PostCovid
# 1  Good hotel, great location  This is a great pl...  2023-08-01  PostCovid
# 2  Good place for a decent price. Good place good...  2022-10-01  PostCovid
# 3  Great Location and great staff. The IBIS was a...  2023-08-01  PostCovid
# 4  Good for budget stay. I stayed there for 7 day...  2022-08-01  PostCovid

# %%
##filter for year >= 2015
df['date_of_stay'] = pd.to_datetime(df['date_of_stay'], format='Date of stay: %B %Y')
df_filtered = df[df['date_of_stay'].dt.year >= 2015]

##preprocess text
nltk.download('stopwords')
nltk.download('words')
# Get the list of valid English words
english_words = set(words.words())
# set stopwords
sw = stopwords.words('english')
sw.append('ibis')
stop_words = set(sw)
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Chen
# [nltk_data]     Wei\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package words to C:\Users\Chen
# [nltk_data]     Wei\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
def preprocess_text(text):
    tokens = word_tokenize(text)
    tokens = [word for word in tokens if word.isalnum()]
    tokens = [word.lower() for word in tokens]
    tokens = [lemmatizer.lemmatize(word) for word in tokens]
    return tokens

# %%
def remove_non_english_words(text, valid_words):
    tokens = word_tokenize(text)
    ans = [w for w in tokens if w.lower() in valid_words]
    return ' '.join(ans)

def remove_stopwords(text):
    tokens = word_tokenize(text)
    ans = [w for w in tokens if w.lower() not in stop_words]
    return ' '.join(ans)

# %%
df_filtered['cleaned_review'] = df_filtered['cleaned_review'].apply(remove_stopwords)
df_filtered['cleaned_review'] = df_filtered['cleaned_review'].apply(remove_non_english_words, valid_words=english_words)
df_filtered['tokens'] = df_filtered['cleaned_review'].apply(preprocess_text)
# Out:
# C:\Users\Chen Wei\AppData\Local\Temp\ipykernel_10868\2710312924.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['cleaned_review'] = df_filtered['cleaned_review'].apply(remove_stopwords)
# C:\Users\Chen Wei\AppData\Local\Temp\ipykernel_10868\2710312924.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['cleaned_review'] = df_filtered['cleaned_review'].apply(remove_non_english_words, valid_words=english_words)
# C:\Users\Chen Wei\AppData\Local\Temp\ipykernel_10868\2710312924.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['tokens'] = df_filtered['cleaned_review'].apply(preprocess_text)

# %%
df_precovid = df_filtered[df_filtered['covid'] == 'PreCovid']
df_precovid.head()
# Out:
#     Unnamed: 0 date_of_stay traveller_username  \
# 66          66   2019-12-01           Beatrice
# 67          67   2020-01-01             dinu79
# 68          68   2019-10-01           Marsha F
# 69          69   2019-10-01     Geoff_and_Juls
# 70          70   2019-10-01       Gianluca3008
#
#                                     review_title  \
# 66                                    Cozy Hotel
# 67  Smart, Clean, Good Location, Value for money
# 68                          Wonderful experience
# 69                       Great Base for Tourists
# 70                                 BEST LOCATION
#
#                                           review_text travel_type  \
# 66  I spent 2 night at this hotel and all the serv...         NaN
# 67  This was my second stay at Ibis Bencoolen.   B...         NaN
# 68  This was our first time at this hotel, and won...         NaN
# 69  Firstly, the good points: Comfortable and clea...         NaN
# 70  Very comfortable hotel, nice staff, totally in...         NaN
#
#        traveller_country_origin  traveller_total_contributions  \
# 66             Batam, Indonesia                            8.0
# 67  Dubai, United Arab Emirates                          212.0
# 68             Gatineau, Canada                           32.0
# 69              Mellieha, Malta                          276.0
# 70                  Rome, Italy                         2192.0
#
#     traveller_total_helpful_contributions  rating1  rating2  rating  \
# 66                                   13.0      5.0      NaN     5.0
# 67                                   53.0      4.0      NaN     4.0
# 68                                   45.0      4.0      NaN     4.0
# 69                                  169.0      4.0      NaN     4.0
# 70                                  280.0      NaN      4.0     4.0
#
#     valid_rating     label                                     cleaned_review  \
# 66          True  Positive  cozy hotel spend night hotel service provide h...
# 67          True  Positive  smart clean good location value money second s...
# 68          True  Positive  wonderful experience first time hotel win last...
# 69          True  Positive  great base tourist firstly good point comforta...
# 70          True  Positive  good location comfortable hotel nice staff tot...
#
#                                       combined_review        date     covid  \
# 66  Cozy Hotel I spent 2 night at this hotel and a...  2019-12-01  PreCovid
# 67  Smart, Clean, Good Location, Value for money T...  2020-01-01  PreCovid
# 68  Wonderful experience This was our first time a...  2019-10-01  PreCovid
# 69  Great Base for Tourists Firstly, the good poin...  2019-10-01  PreCovid
# 70  BEST LOCATION Very comfortable hotel, nice sta...  2019-10-01  PreCovid
#
#                                                tokens
# 66  [cozy, hotel, spend, night, hotel, service, pr...
# 67  [smart, clean, good, location, value, money, s...
# 68  [wonderful, experience, first, time, hotel, wi...
# 69  [great, base, tourist, firstly, good, point, c...
# 70  [good, location, comfortable, hotel, nice, sta...

# %%
df_postcovid = df_filtered[df_filtered['covid'] == 'PostCovid']
df_postcovid.head()
# Out:
#    Unnamed: 0 date_of_stay traveller_username  \
# 0           0   2023-08-01   Love_Life_Sydney
# 1           1   2023-08-01            Bilal S
# 2           2   2022-10-01   Anthony Fernando
# 3           3   2023-08-01            Mjkc204
# 4           4   2022-08-01         Aung Nanda
#
#                       review_title  \
# 0            Clean and comfortable
# 1      Good hotel, great location
# 2   Good place for a decent price.
# 3  Great Location and great staff.
# 4            Good for budget stay.
#
#                                          review_text  \
# 0  Hotel rooms in Singapore are so expensive so t...
# 1  This is a great place! Location is great but t...
# 2  Good place good price  Easy access to the city...
# 3  The IBIS was a neat and tidy hotel in line wit...
# 4  I stayed there for 7 days. It was a nice locat...
#
#                          travel_type     traveller_country_origin  \
# 0   Trip type: Travelled as a couple            Sydney, Australia
# 1   Trip type: Travelled with family               Houston, Texas
# 2  Trip type: Travelled with friends  Dubai, United Arab Emirates
# 3          Trip type: Travelled solo        Ellenbrook, Australia
# 4   Trip type: Travelled on business  Dubai, United Arab Emirates
#
#    traveller_total_contributions  traveller_total_helpful_contributions  \
# 0                         2302.0                                  871.0
# 1                            4.0                                    NaN
# 2                           39.0                                   38.0
# 3                           37.0                                   19.0
# 4                            3.0                                    4.0
#
#    rating1  rating2  rating  valid_rating     label  \
# 0      NaN      4.0     4.0          True  Positive
# 1      5.0      NaN     5.0          True  Positive
# 2      5.0      NaN     5.0          True  Positive
# 3      5.0      NaN     5.0          True  Positive
# 4      NaN      4.0     4.0          True  Positive
#
#                                       cleaned_review  \
# 0  clean comfortable hotel room expensive find de...
# 1  good hotel great location great place location...
# 2  good place decent price good place good price ...
# 3  great location great staff neat tidy hotel lin...
# 4  good budget stay stay day nice location seven ...
#
#                                      combined_review        date      covid  \
# 0  Clean and comfortable Hotel rooms in Singapore...  2023-08-01  PostCovid
# 1  Good hotel, great location  This is a great pl...  2023-08-01  PostCovid
# 2  Good place for a decent price. Good place good...  2022-10-01  PostCovid
# 3  Great Location and great staff. The IBIS was a...  2023-08-01  PostCovid
# 4  Good for budget stay. I stayed there for 7 day...  2022-08-01  PostCovid
#
#                                               tokens
# 0  [clean, comfortable, hotel, room, expensive, f...
# 1  [good, hotel, great, location, great, place, l...
# 2  [good, place, decent, price, good, place, good...
# 3  [great, location, great, staff, neat, tidy, ho...
# 4  [good, budget, stay, stay, day, nice, location...

# %% [markdown]
# ## Unigrams Cosine Similarity

# %% [markdown]
# ### Get top 10 for topics

# %%
##Generate LDA dictionary and corpus
pre_dict = corpora.Dictionary(df_precovid['tokens'])
pre_corpus = [pre_dict.doc2bow(text) for text in df_precovid['tokens']]

# %%
## Check optimal number of topics
lda = gensim.models.ldamodel.LdaModel
pre_ldamodel = lda(pre_corpus, num_topics=5, id2word=pre_dict, passes=15)

# %%
# Show topics with different relevance values
# For example, set topn=10 to display the top 10 terms per topic
topics_with_high_relevance = pre_ldamodel.show_topics(num_topics=5, num_words=10)
topics_with_low_relevance = pre_ldamodel.show_topics(num_topics=5, num_words=5)  # Lower relevance

# Print and examine the topics
print("Topics with high relevance:")
for topic_id, topic in topics_with_high_relevance:
    print(f"Topic {topic_id}: {topic}")

print("\nTopics with low relevance:")
for topic_id, topic in topics_with_low_relevance:
    print(f"Topic {topic_id}: {topic}")
# Out:
# Topics with high relevance:
# Topic 0: 0.026*"hotel" + 0.023*"shower" + 0.019*"food" + 0.015*"also" + 0.012*"use" + 0.011*"hot" + 0.011*"water" + 0.009*"area" + 0.009*"court" + 0.008*"however"
# Topic 1: 0.040*"room" + 0.020*"hotel" + 0.017*"stay" + 0.012*"good" + 0.012*"bed" + 0.012*"water" + 0.011*"staff" + 0.010*"one" + 0.010*"free" + 0.010*"service"
# Topic 2: 0.036*"team" + 0.022*"stay" + 0.020*"hotel" + 0.016*"answer" + 0.016*"care" + 0.015*"matter" + 0.014*"reservation" + 0.013*"customer" + 0.013*"one" + 0.012*"much"
# Topic 3: 0.041*"hotel" + 0.030*"room" + 0.026*"stay" + 0.023*"good" + 0.018*"great" + 0.017*"location" + 0.012*"staff" + 0.012*"walk" + 0.011*"clean" + 0.011*"check"
# Topic 4: 0.048*"hotel" + 0.035*"good" + 0.025*"room" + 0.025*"location" + 0.019*"clean" + 0.017*"staff" + 0.017*"stay" + 0.014*"nice" + 0.012*"near" + 0.011*"friendly"
#
# Topics with low relevance:
# Topic 0: 0.026*"hotel" + 0.023*"shower" + 0.019*"food" + 0.015*"also" + 0.012*"use"
# Topic 1: 0.040*"room" + 0.020*"hotel" + 0.017*"stay" + 0.012*"good" + 0.012*"bed"
# Topic 2: 0.036*"team" + 0.022*"stay" + 0.020*"hotel" + 0.016*"answer" + 0.016*"care"
# Topic 3: 0.041*"hotel" + 0.030*"room" + 0.026*"stay" + 0.023*"good" + 0.018*"great"
# Topic 4: 0.048*"hotel" + 0.035*"good" + 0.025*"room" + 0.025*"location" + 0.019*"clean"

# %%
topic_words = []
for i in range(5):
    top_10_ids = pre_ldamodel.get_topic_terms(i, 10)
    top_words = [pre_dict[ind] for ind, val in top_10_ids]
    topic_words.append(top_words)

# %%
topic_words
# Out:
# [['hotel',
#   'shower',
#   'food',
#   'also',
#   'use',
#   'hot',
#   'water',
#   'area',
#   'court',
#   'however'],
#  ['room',
#   'hotel',
#   'stay',
#   'good',
#   'bed',
#   'water',
#   'staff',
#   'one',
#   'free',
#   'service'],
#  ['team',
#   'stay',
#   'hotel',
#   'answer',
#   'care',
#   'matter',
#   'reservation',
#   'customer',
#   'one',
#   'much'],
#  ['hotel',
#   'room',
#   'stay',
#   'good',
#   'great',
#   'location',
#   'staff',
#   'walk',
#   'clean',
#   'check'],
#  ['hotel',
#   'good',
#   'room',
#   'location',
#   'clean',
#   'staff',
#   'stay',
#   'nice',
#   'near',
#   'friendly']]

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfTransformer
import scipy.sparse

# %%
df_precovid['vec_tokens'] = df_precovid['tokens'].apply(lambda x: ' '.join(x))
# Out:
# C:\Users\Chen Wei\AppData\Local\Temp\ipykernel_10868\1014971942.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_precovid['vec_tokens'] = df_precovid['tokens'].apply(lambda x: ' '.join(x))

# %%
df_precovid['vec_tokens']
# Out:
# 66      cozy hotel spend night hotel service provide h...
# 67      smart clean good location value money second s...
# 68      wonderful experience first time hotel win last...
# 69      great base tourist firstly good point comforta...
# 70      good location comfortable hotel nice staff tot...
#                               ...
# 2274    perfect location lovely two day stop complemen...
# 2275    great hotel place perfect day reasonably good ...
# 2277    budget hotel good location partner stay part l...
# 2280    convenient location clean room friendly staff ...
# 2286    perfect hotel fantastic give expensive country...
# Name: vec_tokens, Length: 2141, dtype: object

# %%
vectorizer = CountVectorizer()
transformer = TfidfTransformer()

precovid_vec = vectorizer.fit_transform(df_precovid['vec_tokens'])
precovid_trf = transformer.fit_transform(precovid_vec)

# %%
topic_words[0]
# Out:
# ['hotel',
#  'shower',
#  'food',
#  'also',
#  'use',
#  'hot',
#  'water',
#  'area',
#  'court',
#  'however']

# %%
cos_res = {}
for i in range(5):
    topic_words_vec = vectorizer.transform(topic_words[i])
    topic_words_trf = transformer.transform(topic_words_vec)
    r = cosine_similarity(precovid_trf, topic_words_trf)
    cos_sim = np.rad2deg(np.arccos(r))
    
    mid_res = []
    for j in cos_sim:
        average_cos_sim = ((j == 90).sum()/len(j))
        mid_res.append(average_cos_sim)
    cos_res[i] = mid_res

# %%
df_c = df_precovid.reset_index()

# %%
sentences_used = set()
for i in cos_res:
    print(f"Sentences for topic {i}:")
    for j in range(len(cos_res[i])):
        if cos_res[i][j] < 0.6:
            print(f"Sentence: {j}:")
            sentences_used.add(j)
            print(df_c.loc[j, 'vec_tokens'])
# Out:
# Sentences for topic 0:
# Sentence: 24:
# budget friendly superb location hotel room fuss free clean plenty affordable food around hotel student area away bus stop right front hotel also provide self service laundry room refillable hot cold water dispenser come certainly stay
# Sentence: 44:
# fantastic hotel great price food school stay hotel international conference attend actually never stay first time stay hotel first foremost room great somewhat small decent sized room ample usual amenity coat hanger iron board desk outlet hotel phone bottled water everything else bed comfortable like hotel bed allow full night rest room great well every time room get clean well bathroom room great well spacious hot water water pressure perfect furthermore hotel weak time sometimes
# Sentence: 47:
# excellent hotel time come airport allow check instantly without extra charge awesome stay king size bed room near min walk little hotel also bus stop great location hotel service good lot food court min walk distance highly recommend hotel
# Sentence: 67:
# nightmare almost aspect stay day hotel nightmare block hot sleep bed bad quality mattress restaurant small breakfast wait minute seat din water card give use offense big trouble security explain card excuse hotel room old lift minute conclude never go hotel
# Sentence: 109:
# room bit small breakfast check weekend stay hotel location nice close station take exit turn right walk bit ahead lobby spacious plenty lounge space quite number hotel area room however bit small shower weak well breakfast menu dish go deeply western local dish adequate variety location perhaps plus point hotel opinion
# Sentence: 110:
# good location location hotel good easily commute different area staff friendly hospitable free handy mobile phone practical traveler loan use personal hot spot call different major country certain country free sadly include list check check fast would recommend hotel need sleep rest awhile practical stay long time inside hotel room might small tourist room fit well
# budget hotel good location partner stay part large group arrive extremely tired specifically check non smoking room lug bag level open door hit stench cigarette room hotel staff change room immediately complain apology lug back level fluorescent light flicker top bed sheet bed next morning ask fix light fix sheet fold put bed little disappointing lazy entire day suffer sore back due bed partner also feel bed uncomfortable enjoy quality night sleep budget hotel stay elsewhere fifth night sleep get comfortable position bed breakfast good although much western variety taste restaurant excellent dinner overall good clean modern hotel budget linen change room service pool gym although free access gym min away bed poor quality win stay
# Sentence: 2139:
# convenient location clean room friendly staff well locate area within minute walk distance near bus stop front hotel connect various downtown venue clean bright room comfy bed need good night rest staff friendly quick respond request basic hotel necessary amenity make stay comfortable enough
# Sentence: 2140:
# perfect hotel fantastic give expensive country hotel clean central friendly much money exactly need spend day explore come home bed room exactly want back

# %%
unused_sentences = []
for i in range(len(df_c)):
    if i not in sentences_used:
        unused_sentences.append(i)

print(len(unused_sentences))
# Out:
# 222

# %% [markdown]
# ## Bigram Cosine Similarity

# %%
clean_precovid = df_precovid['cleaned_review'].apply(preprocess_text)
clean_precovid = clean_precovid.apply(lambda x: ' '.join(x))
clean_postcovid = df_postcovid['cleaned_review'].apply(preprocess_text)
clean_postcovid = clean_postcovid.apply(lambda x: ' '.join(x))

# %%
from nltk import ngrams
bigrams_precovid = []
bigrams_postcovid = []

for d in clean_precovid:
    tokens = word_tokenize(d)
    bigrams_precovid.append(["_".join(w) for w in ngrams(tokens, 2)])

for e in clean_postcovid:
    tokens = word_tokenize(e)
    bigrams_postcovid.append(['_'.join(w) for w in ngrams(tokens, 2)])

# %%
##Generate LDA dictionary and corpus
pre_dict = corpora.Dictionary(bigrams_precovid)
pre_corpus = [pre_dict.doc2bow(text) for text in bigrams_precovid]

# %%
## Check optimal number of topics
lda = gensim.models.ldamodel.LdaModel
pre_ldamodel = lda(pre_corpus, num_topics=5, id2word=pre_dict, passes=15)

# %%
##Generate LDA dictionary and corpus
post_dict = corpora.Dictionary(bigrams_postcovid)
post_corpus = [post_dict.doc2bow(text) for text in bigrams_postcovid]

# %%
## Check optimal number of topics
lda = gensim.models.ldamodel.LdaModel
post_ldamodel = lda(post_corpus, num_topics=5, id2word=post_dict, passes=15)

# %%
# Show topics with different relevance values
# For example, set topn=10 to display the top 10 terms per topic
topics_with_high_relevance = post_ldamodel.show_topics(num_topics=4, num_words=10)
topics_with_low_relevance = post_ldamodel.show_topics(num_topics=4, num_words=5)  # Lower relevance

# Print and examine the topics
print("Topics with high relevance:")
for topic_id, topic in topics_with_high_relevance:
    print(f"Topic {topic_id}: {topic}")

print("\nTopics with low relevance:")
for topic_id, topic in topics_with_low_relevance:
    print(f"Topic {topic_id}: {topic}")
# Out:
# Topics with high relevance:
# Topic 4: 0.004*"clean_room" + 0.003*"walk_distance" + 0.003*"come_back" + 0.003*"friendly_service" + 0.003*"customer_service" + 0.003*"definitely_stay" + 0.003*"would_definitely" + 0.003*"short_walk" + 0.002*"good_location" + 0.002*"next_door"
# Topic 2: 0.005*"great_location" + 0.003*"hotel_great" + 0.003*"clean_hotel" + 0.003*"hotel_room" + 0.003*"cancel_booking" + 0.003*"stay_hotel" + 0.003*"room_good" + 0.003*"staff_friendly" + 0.003*"good_hotel" + 0.002*"next_door"
# Topic 0: 0.003*"walk_distance" + 0.003*"engineering_team" + 0.003*"bed_comfortable" + 0.003*"small_room" + 0.003*"good_location" + 0.003*"cleaning_staff" + 0.003*"extra_benefit" + 0.003*"room_small" + 0.002*"good_place" + 0.002*"reservation_breakfast"
# Topic 1: 0.006*"value_money" + 0.003*"location_great" + 0.003*"good_hotel" + 0.002*"bed_comfortable" + 0.002*"excellent_service" + 0.002*"great_location" + 0.002*"buffet_breakfast" + 0.002*"good_value" + 0.002*"check_good" + 0.002*"queue_check"
#
# Topics with low relevance:
# Topic 2: 0.005*"great_location" + 0.003*"hotel_great" + 0.003*"clean_hotel" + 0.003*"hotel_room" + 0.003*"cancel_booking"
# Topic 0: 0.003*"walk_distance" + 0.003*"engineering_team" + 0.003*"bed_comfortable" + 0.003*"small_room" + 0.003*"good_location"
# Topic 3: 0.004*"hotel_good" + 0.003*"good_location" + 0.003*"stay_day" + 0.002*"room_small" + 0.002*"location_great"
# Topic 4: 0.004*"clean_room" + 0.003*"walk_distance" + 0.003*"come_back" + 0.003*"friendly_service" + 0.003*"customer_service"

# %%
topic_words = []
for i in range(5):
    top_10_ids = pre_ldamodel.get_topic_terms(i, 10)
    top_words = [pre_dict[ind] for ind, val in top_10_ids]
    topic_words.append(top_words)

# %%
topic_words
# Out:
# [['stay_hotel',
#   'room_clean',
#   'good_location',
#   'minute_walk',
#   'great_location',
#   'good_experience',
#   'value_money',
#   'come_back',
#   'orchard_road',
#   'room_comfortable'],
#  ['good_location',
#   'bus_stop',
#   'stay_hotel',
#   'room_clean',
#   'great_location',
#   'hotel_room',
#   'good_hotel',
#   'walk_distance',
#   'location_stay',
#   'minute_walk'],
#  ['bus_stop',
#   'good_location',
#   'minute_walk',
#   'front_hotel',
#   'walk_distance',
#   'staff_friendly',
#   'room_clean',
#   'great_hotel',
#   'hotel_good',
#   'great_location'],
#  ['good_hotel',
#   'value_money',
#   'comfortable_bed',
#   'minute_walk',
#   'budget_hotel',
#   'room_small',
#   'staff_friendly',
#   'bed_comfortable',
#   'great_location',
#   'good_location'],
#  ['room_small',
#   'good_location',
#   'staff_friendly',
#   'walk_distance',
#   'good_value',
#   'value_money',
#   'great_location',
#   'friendly_helpful',
#   'room_clean',
#   'bus_stop']]

# %%
df_precovid['vec_tokens'] = df_precovid['tokens'].apply(lambda x: ["_".join(w) for w in ngrams(x, 2)])
# Out:
# C:\Users\Chen Wei\AppData\Local\Temp\ipykernel_10868\2572606165.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_precovid['vec_tokens'] = df_precovid['tokens'].apply(lambda x: ["_".join(w) for w in ngrams(x, 2)])

# %%
df_precovid['vec'] = df_precovid['vec_tokens'].apply(lambda x: ' '.join(x))
# Out:
# C:\Users\Chen Wei\AppData\Local\Temp\ipykernel_10868\416102357.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_precovid['vec'] = df_precovid['vec_tokens'].apply(lambda x: ' '.join(x))

# %%
vectorizer = CountVectorizer()
transformer = TfidfTransformer()

precovid_vec = vectorizer.fit_transform(df_precovid['vec'])
precovid_trf = transformer.fit_transform(precovid_vec)

# %%
cos_res = {}
for i in range(5):
    topic_words_vec = vectorizer.transform(topic_words[i])
    topic_words_trf = transformer.transform(topic_words_vec)
    r = cosine_similarity(precovid_trf, topic_words_trf)
    cos_sim = np.rad2deg(np.arccos(r))
    
    mid_res = []
    for j in cos_sim:
        average_cos_sim = ((j == 90).sum()/len(j))
        mid_res.append(average_cos_sim)
    cos_res[i] = mid_res

# %%
df_c = df_precovid.reset_index()

# %%
sentences_used = set()
for i in cos_res:
    print(f"Sentences for topic {i}:")
    for j in range(len(cos_res[i])):
        if cos_res[i][j] < 0.6:
            print(f"Sentence: {j}:")
            sentences_used.add(j)
            print(df_c.loc[j, 'vec_tokens'])
# Out:
# Sentences for topic 0:
# Sentence: 2130:
# ['stay_come', 'come_back', 'back_second', 'second_stay', 'stay_room', 'room_clean', 'clean_size', 'size_good', 'good_bed', 'bed_pillow', 'pillow_great', 'great_even', 'even_well', 'well_well', 'well_know', 'know_star', 'star_hotel', 'hotel_city', 'city_sleep', 'sleep_really', 'really_well', 'well_restaurant', 'restaurant_great', 'great_food', 'food_beverage', 'beverage_good', 'good_location', 'location_public', 'public_transport', 'transport_within', 'within_reach', 'reach_bus', 'bus_stop', 'stop_right', 'right_front', 'front_hotel', 'hotel_minute', 'minute_walk', 'walk_close', 'close_station', 'station_overall', 'overall_great', 'great_hotel', 'hotel_stay', 'stay_good', 'good_value', 'value_money', 'money_satisfied', 'satisfied_come', 'come_back', 'back_sure']
# Sentences for topic 1:
# Sentence: 1239:
# ['good_hotel', 'hotel_great', 'great_location', 'location_stay', 'stay_couple', 'couple_night', 'night_june', 'june_really', 'really_complaint', 'complaint_staff', 'staff_friendly', 'friendly_helpful', 'helpful_room', 'room_clean', 'clean_travel', 'travel_child', 'child_lot', 'lot_luggage', 'luggage_aware', 'aware_room', 'room_quite', 'quite_small', 'small_breakfast', 'breakfast_buffet', 'buffet_good', 'good_selection', 'selection_food', 'food_taste', 'taste_excellent', 'excellent_another', 'another_good', 'good_plus', 'plus_hotel', 'hotel_location', 'location_walk', 'walk_distance', 'distance_little', 'little_technically', 'technically_even', 'even_good', 'good_number', 'number_affordable', 'affordable_place', 'place_eat', 'eat_near', 'near_eleven', 'eleven_next', 'next_door', 'door_bus', 'bus_stop', 'stop_right', 'right_outside']
# Sentence: 1274:
# ['perfect_location', 'location_value', 'value_money', 'money_let', 'let_start', 'start_location', 'location_locate', 'locate_along', 'along_street', 'street_minute', 'minute_walk', 'walk_station', 'station_airport', 'airport_access', 'access_line', 'line_minute', 'minute_village', 'village_junction', 'junction_mall', 'mall_art', 'art_museum', 'museum_street', 'street_lane', 'lane_street', 'street_liang', 'liang_seah', 'seah_street', 'street_reach', 'reach_within', 'within_walk', 'walk_distance', 'distance_locate', 'locate_heart', 'heart_cultural', 'cultural_district', 'district_hotel', 'hotel_room', 'room_clean', 'clean_modern', 'modern_design', 'design_plus', 'plus_bed', 'bed_technology', 'technology_great', 'great_really', 'really_love', 'love_self', 'self_service', 'service_laundry', 'laundry_floor', 'floor_good', 'good_food', 'food_free', 'free_excellent', 'excellent_staff', 'staff_friendly', 'friendly_specially', 'specially_old', 'old_lady', 'lady_clean', 'clean_room', 'room_th', 'th_definitely', 'definitely_stay', 'stay_hotel', 'hotel_recommend', 'recommend_hotel', 'hotel_friend', 'friend_visit', 'visit_right', 'right_also', 'also_love']
# Sentence: 2045:
# ['clean_hotel', 'hotel_friendly', 'friendly_stuff', 'stuff_good', 'good_location', 'location_stay', 'stay_hotel', 'hotel_night', 'night_expect', 'expect_pretentious', 'pretentious_luxury', 'luxury_know', 'know_find', 'find_clean', 'clean_hotel', 'hotel_room', 'room_offer', 'offer_standard', 'standard_need', 'need_consider', 'consider_room', 'room_lodge', 'lodge_night', 'night_wonderful', 'wonderful_stay', 'stay_location', 'location_perfect', 'perfect_close', 'close_also', 'also_walk', 'walk_distance', 'distance_attraction', 'attraction_like', 'like_orchard', 'orchard_kampong', 'kampong_glam', 'glam_raffle', 'raffle_city', 'city_mention', 'mention_stuff', 'stuff_hotel', 'hotel_outstanding', 'outstanding_friendly', 'friendly_helpful', 'helpful_surround', 'surround_area', 'area_safe']
# Sentences for topic 2:
# Sentence: 227:
# ['great_hotel', 'hotel_good', 'good_location', 'location_spacious', 'spacious_room', 'room_awesome', 'awesome_breakfast', 'breakfast_option', 'option_spread', 'spread_bus', 'bus_stop', 'stop_door', 'door_station', 'station_walk', 'walk_distance', 'distance_around', 'around_corner', 'corner_staff', 'staff_courteous', 'courteous_helpful', 'helpful_water', 'water_refill', 'refill_pain', 'pain_overall', 'overall_good', 'good_hotel', 'hotel_afford']
# Sentence: 1239:
# ['good_hotel', 'hotel_great', 'great_location', 'location_stay', 'stay_couple', 'couple_night', 'night_june', 'june_really', 'really_complaint', 'complaint_staff', 'staff_friendly', 'friendly_helpful', 'helpful_room', 'room_clean', 'clean_travel', 'travel_child', 'child_lot', 'lot_luggage', 'luggage_aware', 'aware_room', 'room_quite', 'quite_small', 'small_breakfast', 'breakfast_buffet', 'buffet_good', 'good_selection', 'selection_food', 'food_taste', 'taste_excellent', 'excellent_another', 'another_good', 'good_plus', 'plus_hotel', 'hotel_location', 'location_walk', 'walk_distance', 'distance_little', 'little_technically', 'technically_even', 'even_good', 'good_number', 'number_affordable', 'affordable_place', 'place_eat', 'eat_near', 'near_eleven', 'eleven_next', 'next_door', 'door_bus', 'bus_stop', 'stop_right', 'right_outside']
# Sentence: 1814:
# ['great_location', 'location_comfortable', 'comfortable_hotel', 'hotel_hotel', 'hotel_easy', 'easy_walk', 'walk_distance', 'distance_st', 'st_little', 'little_junction', 'junction_plenty', 'plenty_market', 'market_stall', 'stall_food', 'food_clothe', 'clothe_browse', 'browse_close', 'close_staff', 'staff_friendly', 'friendly_restaurant', 'restaurant_good', 'good_local', 'local_dish', 'dish_bus', 'bus_stop', 'stop_front', 'front_hotel', 'hotel_hop', 'hop_hop', 'hop_bus', 'bus_tour', 'tour_local', 'local_transport', 'transport_route', 'route_minute', 'minute_walk', 'walk_hotel', 'hotel_comfortable', 'comfortable_bed', 'bed_great', 'great_base', 'base_explore']
# Sentence: 2083:
# ['good_location', 'location_friendly', 'friendly_staff', 'staff_comfortable', 'comfortable_bed', 'bed_location', 'location_great', 'great_min', 'min_walk', 'walk_station', 'station_bus', 'bus_stop', 'stop_front', 'front_hotel', 'hotel_several', 'several_mall', 'mall_hawker', 'hawker_within', 'within_walk', 'walk_distance', 'distance_check', 'check_staff', 'staff_friendly', 'friendly_attentive', 'attentive_early', 'early_check', 'check_late', 'late_check', 'check_possible', 'possible_really', 'really_great', 'great_bed', 'bed_comfortable', 'comfortable_bathroom', 'bathroom_clean', 'clean_unlimited', 'unlimited_free', 'free_work', 'work_well', 'well_throughout', 'throughout_hotel', 'hotel_buffet', 'buffet_breakfast', 'breakfast_good', 'good_plenty', 'plenty_option', 'option_everyone']
# Sentence: 2130:
# ['stay_come', 'come_back', 'back_second', 'second_stay', 'stay_room', 'room_clean', 'clean_size', 'size_good', 'good_bed', 'bed_pillow', 'pillow_great', 'great_even', 'even_well', 'well_well', 'well_know', 'know_star', 'star_hotel', 'hotel_city', 'city_sleep', 'sleep_really', 'really_well', 'well_restaurant', 'restaurant_great', 'great_food', 'food_beverage', 'beverage_good', 'good_location', 'location_public', 'public_transport', 'transport_within', 'within_reach', 'reach_bus', 'bus_stop', 'stop_right', 'right_front', 'front_hotel', 'hotel_minute', 'minute_walk', 'walk_close', 'close_station', 'station_overall', 'overall_great', 'great_hotel', 'hotel_stay', 'stay_good', 'good_value', 'value_money', 'money_satisfied', 'satisfied_come', 'come_back', 'back_sure']
# Sentence: 2139:
# ['convenient_location', 'location_clean', 'clean_room', 'room_friendly', 'friendly_staff', 'staff_well', 'well_locate', 'locate_area', 'area_within', 'within_minute', 'minute_walk', 'walk_distance', 'distance_near', 'near_bus', 'bus_stop', 'stop_front', 'front_hotel', 'hotel_connect', 'connect_various', 'various_downtown', 'downtown_venue', 'venue_clean', 'clean_bright', 'bright_room', 'room_comfy', 'comfy_bed', 'bed_need', 'need_good', 'good_night', 'night_rest', 'rest_staff', 'staff_friendly', 'friendly_quick', 'quick_respond', 'respond_request', 'request_basic', 'basic_hotel', 'hotel_necessary', 'necessary_amenity', 'amenity_make', 'make_stay', 'stay_comfortable', 'comfortable_enough']
# Sentences for topic 3:
# Sentence: 305:
# ['good_hotel', 'hotel_check', 'check_fast', 'fast_friendly', 'friendly_room', 'room_locate', 'locate_th', 'th_floor', 'floor_nice', 'nice_view', 'view_typical', 'typical_room', 'room_small', 'small_compact', 'compact_clean', 'clean_room', 'room_comfortable', 'comfortable_bed', 'bed_clean', 'clean_bathroom', 'bathroom_flat', 'flat_screen', 'screen_small', 'small_room', 'room_safe', 'safe_complimentary', 'complimentary_complimentary', 'complimentary_coffee', 'coffee_tea', 'tea_breakfast', 'breakfast_serve', 'serve_buffet', 'buffet_style', 'style_eat', 'eat_hotel', 'hotel_meal', 'meal_comment', 'comment_taste', 'taste_value', 'value_food', 'food_price', 'price_breakfast', 'breakfast_find', 'find_pretty', 'pretty_expensive', 'expensive_give', 'give_le', 'le_minute', 'minute_walk', 'walk_away', 'away_public', 'public_bus', 'bus_door', 'door_station', 'station_le', 'le_minute', 'minute_away', 'away_nice', 'nice_hotel', 'hotel_decent', 'decent_value', 'value_money', 'money_pay']
# Sentence: 624:
# ['typical_hotel', 'hotel_least', 'least_one', 'one_stay', 'stay_one', 'one_modern', 'modern_clean', 'clean_functional', 'functional_end', 'end_day', 'day_budget', 'budget_hotel', 'hotel_firmly', 'firmly_frill', 'frill_category', 'category_mean', 'mean_room', 'room_small', 'small_fairly', 'fairly_basic', 'basic_neither', 'neither_room', 'room_public', 'public_facility', 'facility_anything', 'anything_even', 'even_remotely', 'remotely_suggest', 'suggest_luxury', 'luxury_service', 'service_good', 'good_breakfast', 'breakfast_plentiful', 'plentiful_bed', 'bed_comfortable', 'comfortable_value', 'value_money', 'money_reasonably', 'reasonably_good', 'good_location', 'location_wise', 'wise_really', 'really_central', 'central_anything', 'anything_particular', 'particular_good', 'good_transport', 'transport_connection', 'connection_get', 'get_anywhere', 'anywhere_quickly', 'quickly_without', 'without_drama', 'drama_good', 'good_selection', 'selection_shop', 'shop_restaurant', 'restaurant_food', 'food_court', 'court_essential', 'essential_within', 'within_short', 'short_walk']
# Sentence: 861:
# ['great_budget', 'budget_hotel', 'hotel_convenient', 'convenient_location', 'location_standard', 'standard_room', 'room_small', 'small_functional', 'functional_stay', 'stay_night', 'night_manage', 'manage_storage', 'storage_amazing', 'amazing_staff', 'staff_friendly', 'friendly_couple', 'couple_night', 'night_feel', 'feel_like', 'like_home', 'home_comfortable', 'comfortable_bed', 'bed_room', 'room_bathroom', 'bathroom_spotless', 'spotless_corridor', 'corridor_bit', 'bit_drab', 'drab_hey', 'hey_live', 'live_corridor', 'corridor_minute', 'minute_walk', 'walk_orchard', 'orchard_around', 'around_minute', 'minute_mall', 'mall_minute', 'minute_walk', 'walk_away', 'away_taste', 'taste_bistro', 'bistro_limit', 'limit_menu', 'menu_food', 'food_good', 'good_standard', 'standard_excellent', 'excellent_value', 'value_plus', 'plus_member', 'member_special', 'special_mention', 'mention_staff', 'staff_amazing', 'amazing_priority', 'priority_desk', 'desk_wonderful', 'wonderful_staff', 'staff_taste', 'taste_especially', 'especially_happy', 'happy_one', 'one_plus', 'plus_one', 'one_extra', 'extra_benefit', 'benefit_room', 'room_handy', 'handy_device', 'device_like', 'like_smart', 'smart_phone', 'phone_give', 'give_unlimited', 'unlimited_call', 'call_text', 'text_locally', 'locally_overseas', 'overseas_country', 'country_take', 'take_go', 'go_unlimited', 'unlimited_access', 'access_stay', 'stay_couple', 'couple_time']
# Sentence: 1784:
# ['good_budget', 'budget_hotel', 'hotel_great', 'great_location', 'location_shopping', 'shopping_restaurant', 'restaurant_minute', 'minute_walk', 'walk_hotel', 'hotel_room', 'room_small', 'small_clean', 'clean_staff', 'staff_friendly', 'friendly_helpful', 'helpful_free', 'free_parking', 'parking_provide', 'provide_overall', 'overall_good', 'good_hotel', 'hotel_budget']
# Sentence: 2023:
# ['absolutely_fantastic', 'fantastic_could', 'could_fault', 'fault_amazing', 'amazing_hotel', 'hotel_clean', 'clean_modern', 'modern_hotel', 'hotel_nice', 'nice_spacious', 'spacious_room', 'room_comfortable', 'comfortable_bed', 'bed_great', 'great_facility', 'facility_room', 'room_location', 'location_second', 'second_none', 'none_close', 'close_market', 'market_still', 'still_quiet', 'quiet_room', 'room_station', 'station_minute', 'minute_walk', 'walk_lot', 'lot_restaurant', 'restaurant_doorstep', 'doorstep_large', 'large_size', 'size_eleven', 'eleven_downstairs', 'downstairs_convenient', 'convenient_free', 'free_fast', 'fast_reliable', 'reliable_tiny', 'tiny_fault', 'fault_bar', 'bar_room', 'room_small', 'small_small', 'small_bottle', 'bottle_water', 'water_would', 'would_fit', 'fit_even', 'even_lie', 'lie_thing', 'thing_could', 'could_fault', 'fault_absolutely', 'absolutely_nothing', 'nothing_major', 'major_staff', 'staff_friendly', 'friendly_knowledgeable', 'knowledgeable_fast', 'fast_efficient', 'efficient_check', 'check_check', 'check_complimentary', 'complimentary_check', 'check_lovely', 'lovely_good', 'good_value', 'value_money', 'money_certainly', 'certainly_would', 'would_hesitate', 'hesitate_stay']
# Sentences for topic 4:
# Sentence: 229:
# ['excellent_location', 'location_bus', 'bus_stop', 'stop_door', 'door_helpful', 'helpful_staff', 'staff_spend', 'spend_total', 'total_five', 'five_night', 'night_location', 'location_people', 'people_intend', 'intend_lodge', 'lodge_hotel', 'hotel_might', 'might_find', 'find_follow', 'follow_information', 'information_useful', 'useful_excellent', 'excellent_location', 'location_public', 'public_transport', 'transport_bus', 'bus_stop', 'stop_door', 'door_three', 'three_station', 'station_close', 'close_bus', 'bus_station', 'station_within', 'within_close', 'close_walking', 'walking_distance', 'distance_hotel', 'hotel_surround', 'surround_shop', 'shop_eatery', 'eatery_room', 'room_chain', 'chain_hotel', 'hotel_room', 'room_clean', 'clean_represent', 'represent_good', 'good_value', 'value_money', 'money_room', 'room_small', 'small_electric', 'electric_kettle', 'kettle_charge', 'charge_point', 'point_floor', 'floor_stay', 'stay_quiet', 'quiet_stay', 'stay_th', 'th_floor', 'floor_room', 'room_great', 'great_view', 'view_fast', 'fast_easy', 'easy_log', 'log_problem', 'problem_staff', 'staff_helpful', 'helpful_ask', 'ask_front', 'front_desk', 'desk_small', 'small_leaflet', 'leaflet_show', 'show_use', 'use_public', 'public_transport', 'transport_get', 'get_hotel', 'hotel_major', 'major_tourist']
# Sentence: 566:
# ['nice_hotel', 'hotel_great', 'great_location', 'location_stay', 'stay_night', 'night_recently', 'recently_room', 'room_small', 'small_clean', 'clean_tidy', 'tidy_tea', 'tea_coffee', 'coffee_make', 'make_facility', 'facility_room', 'room_small', 'small_small', 'small_wardrobe', 'wardrobe_clothe', 'clothe_drawer', 'drawer_board', 'board_iron', 'iron_wardrobe', 'wardrobe_small', 'small_safe', 'safe_valuable', 'valuable_daily', 'daily_buffet', 'buffet_breakfast', 'breakfast_nice', 'nice_dish', 'dish_change', 'change_day', 'day_staff', 'staff_friendly', 'friendly_helpful', 'helpful_lot', 'lot_business', 'business_people', 'people_stay', 'stay_hotel', 'hotel_great', 'great_location', 'location_market', 'market_min', 'min_walk', 'walk_little', 'little_min', 'min_walk', 'walk_bus', 'bus_stop', 'stop_front', 'front_hotel', 'hotel_would', 'would_definitely', 'definitely_recommend', 'recommend_hotel', 'hotel_family', 'family_friend']
# Sentence: 756:
# ['good_value', 'value_expensive', 'expensive_spore', 'spore_stay', 'stay_night', 'night_two', 'two_different', 'different_room', 'room_basically', 'basically_budget', 'budget_frill', 'frill_hotel', 'hotel_situate', 'situate_good', 'good_location', 'location_nearby', 'nearby_many', 'many_attraction', 'attraction_street', 'street_little', 'little_quarter', 'quarter_eat', 'eat_place', 'place_nearby', 'nearby_room', 'room_small', 'small_clean', 'clean_basic', 'basic_provide', 'provide_even', 'even_provide', 'provide_iron', 'iron_facility', 'facility_room', 'room_free', 'free_provide', 'provide_taxi', 'taxi_easily', 'easily_available', 'available_special', 'special_pickup', 'pickup_area', 'area_staff', 'staff_friendly', 'friendly_helpful']
# Sentence: 875:
# ['great_location', 'location_good', 'good_price', 'price_hotel', 'hotel_similar', 'similar_hotel', 'hotel_stay', 'stay_locate', 'locate_great', 'great_location', 'location_near', 'near_lot', 'lot_shopping', 'shopping_friendly', 'friendly_helpful', 'helpful_staff', 'staff_room', 'room_clean', 'clean_adequate', 'adequate_size', 'size_come', 'come_comfortable', 'comfortable_bed', 'bed_standard', 'standard_toiletry', 'toiletry_good', 'good_hotel', 'hotel_good', 'good_value', 'value_good', 'good_location', 'location_else', 'else_could', 'could_ask']
# Sentence: 1096:
# ['budget_hotel', 'hotel_top', 'top_class', 'class_staff', 'staff_stay', 'stay_night', 'night_room', 'room_standard', 'standard_sized', 'sized_room', 'room_clean', 'clean_expect', 'expect_disappoint', 'disappoint_staff', 'staff_friendly', 'friendly_helpful', 'helpful_expensive', 'expensive_hotel', 'hotel_particularly', 'particularly_watch', 'watch_fall', 'fall_pound', 'pound_become', 'become_poor', 'poor_currency', 'currency_world', 'world_hotel', 'hotel_represent', 'represent_excellent', 'excellent_value', 'value_money', 'money_excellent', 'excellent_location', 'location_get', 'get_around', 'around_either', 'either_foot', 'foot_public', 'public_transport', 'transport_bus', 'bus_stop', 'stop_outside', 'outside_close', 'close_would', 'would_definitely', 'definitely_recommend', 'recommend_hotel', 'hotel_would', 'would_choose', 'choose_visit']
# Sentence: 1233:
# ['comfortable_stay', 'stay_great', 'great_location', 'location_hotel', 'hotel_locate', 'locate_close', 'close_street', 'street_station', 'station_walk', 'walk_distance', 'distance_nearby', 'nearby_bus', 'bus_stop', 'stop_right', 'right_hotel', 'hotel_move', 'move_around', 'around_city', 'city_convenient', 'convenient_stay', 'stay_room', 'room_clean', 'clean_small', 'small_bathroom', 'bathroom_small', 'small_standard', 'standard_room', 'room_get', 'get_room', 'room_th', 'th_floor', 'floor_view', 'view_city', 'city_amazing', 'amazing_food', 'food_good', 'good_staff', 'staff_helpful', 'helpful_value', 'value_money', 'money_hotel', 'hotel_nice', 'nice_location', 'location_overall']
# Sentence: 1239:
# ['good_hotel', 'hotel_great', 'great_location', 'location_stay', 'stay_couple', 'couple_night', 'night_june', 'june_really', 'really_complaint', 'complaint_staff', 'staff_friendly', 'friendly_helpful', 'helpful_room', 'room_clean', 'clean_travel', 'travel_child', 'child_lot', 'lot_luggage', 'luggage_aware', 'aware_room', 'room_quite', 'quite_small', 'small_breakfast', 'breakfast_buffet', 'buffet_good', 'good_selection', 'selection_food', 'food_taste', 'taste_excellent', 'excellent_another', 'another_good', 'good_plus', 'plus_hotel', 'hotel_location', 'location_walk', 'walk_distance', 'distance_little', 'little_technically', 'technically_even', 'even_good', 'good_number', 'number_affordable', 'affordable_place', 'place_eat', 'eat_near', 'near_eleven', 'eleven_next', 'next_door', 'door_bus', 'bus_stop', 'stop_right', 'right_outside']
# Sentence: 1631:
# ['great_location', 'location_nice', 'nice_staff', 'staff_good', 'good_location', 'location_walk', 'walk_distance', 'distance_street', 'street_lim', 'lim_square', 'square_staff', 'staff_friendly', 'friendly_helpful', 'helpful_breakfast', 'breakfast_perfect', 'perfect_many', 'many_choice', 'choice_room', 'room_small', 'small_clean', 'clean_comfortable', 'comfortable_recommend']
# Sentence: 1947:
# ['need_recently', 'recently_conference', 'conference_convention', 'convention_decent', 'decent_choice', 'choice_value', 'value_money', 'money_min', 'min_walk', 'walk_convention', 'convention_min', 'min_yo', 'yo_station', 'station_nearby', 'nearby_eleven', 'eleven_pharmacy', 'pharmacy_supermarket', 'supermarket_market', 'market_restaurant', 'restaurant_easy', 'easy_walk', 'walk_distance', 'distance_raffle', 'raffle_min', 'min_quay', 'quay_hotel', 'hotel_clean', 'clean_staff', 'staff_friendly', 'friendly_room', 'room_small', 'small_side', 'side_need', 'need_clean', 'clean_bed', 'bed_comfy', 'comfy_breakfast', 'breakfast_think', 'think_steep', 'steep_place', 'place_around', 'around_want', 'want_buffet', 'buffet_good', 'good_value', 'value_money']
# Sentence: 2130:
# ['stay_come', 'come_back', 'back_second', 'second_stay', 'stay_room', 'room_clean', 'clean_size', 'size_good', 'good_bed', 'bed_pillow', 'pillow_great', 'great_even', 'even_well', 'well_well', 'well_know', 'know_star', 'star_hotel', 'hotel_city', 'city_sleep', 'sleep_really', 'really_well', 'well_restaurant', 'restaurant_great', 'great_food', 'food_beverage', 'beverage_good', 'good_location', 'location_public', 'public_transport', 'transport_within', 'within_reach', 'reach_bus', 'bus_stop', 'stop_right', 'right_front', 'front_hotel', 'hotel_minute', 'minute_walk', 'walk_close', 'close_station', 'station_overall', 'overall_great', 'great_hotel', 'hotel_stay', 'stay_good', 'good_value', 'value_money', 'money_satisfied', 'satisfied_come', 'come_back', 'back_sure']

# %%
unused_sentences = []
for i in range(len(df_c)):
    if i not in sentences_used:
        unused_sentences.append(i)

print(len(unused_sentences))
# Out:
# 2120
