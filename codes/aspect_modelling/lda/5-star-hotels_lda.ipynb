# %%
import spacy
import nltk
import re
import string
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
import gensim
from gensim import corpora
import pyLDAvis.gensim
import matplotlib.pyplot as plt
import pyprojroot.here as here

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/ammarbagharib/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
data1 = pd.read_csv(here("data/processed/cleaned_swissotel-the-stamford.csv"))
data2 = pd.read_csv(here("data/processed/cleaned_mbs_total.csv"))
data3 = pd.read_csv(here("data/processed/cleaned_pan-pacific.csv"))
data4 = pd.read_csv(here("data/processed/cleaned_parkroyal-collection-marina-bay.csv"))
data5 = pd.read_csv(here("data/processed/cleaned_fullerton.csv"))
data = pd.concat([data1, data2, data3, data4, data5], ignore_index = True)
print(len(data1))
print(len(data2))
print(len(data3))
print(len(data4))
print(len(data5))
len(data)
# Out:
# 5058
# 10523
# 7430
# 6237
# 6374
# 35622

# %%
reviews = data["lem_review"]
reviews.head()
# Out:
# 0    excellent stay fantastic scenery th stay still...
# 1    pampercation th floor crest suite harbour view...
# 2    excellent location facility conference venue h...
# 3    great experience stay swissotel great staying ...
# 4    decent stay something improve decent stay swis...
# Name: lem_review, dtype: object

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
finder = nltk.collocations.BigramCollocationFinder.from_documents([comment.split() for comment in reviews])
# Filter only those that occur at least 10 times
finder.apply_freq_filter(10)
bigram_scores = finder.score_ngrams(bigram_measures.pmi)

# %%
trigram_measures = nltk.collocations.TrigramAssocMeasures()
finder = nltk.collocations.TrigramCollocationFinder.from_documents([comment.split() for comment in reviews])
# Filter only those that occur at least 10 times
finder.apply_freq_filter(10)
trigram_scores = finder.score_ngrams(trigram_measures.pmi)

# %%
bigram_pmi = pd.DataFrame(bigram_scores)
bigram_pmi.columns = ['bigram', 'pmi']
bigram_pmi.sort_values(by='pmi', axis = 0, ascending = False, inplace = True)
bigram_pmi
# Out:
#                      bigram        pmi
# 0            (pina, colada)  17.327900
# 1        (laurent, perrier)  16.825399
# 2              (foie, gras)  16.819753
# 3              (sri, lanka)  16.590934
# 4      (giovanni, viterale)  16.368542
# ...                     ...        ...
# 25131        (would, hotel)  -3.678364
# 25132           (hotel, we)  -3.802143
# 25133         (club, hotel)  -3.824414
# 25134    (staff, singapore)  -3.899773
# 25135          (hotel, bay)  -4.039499
#
# [25136 rows x 2 columns]

# %%
trigram_pmi = pd.DataFrame(trigram_scores)
trigram_pmi.columns = ['trigram', 'pmi']
trigram_pmi.sort_values(by='pmi', axis = 0, ascending = False, inplace = True)
trigram_pmi
# Out:
#                      trigram        pmi
# 0               (ku, de, ta)  29.440543
# 1           (din, tai, fung)  28.886434
# 2       (ruth, chris, steak)  27.490997
# 3     (mass, rapid, transit)  27.335074
# 4           (scan, qr, code)  27.199812
# ...                      ...        ...
# 8066    (hotel, room, staff)  -0.481435
# 8067    (hotel, hotel, good)  -0.770127
# 8068    (stay, hotel, hotel)  -0.771328
# 8069    (hotel, hotel, room)  -0.931946
# 8070     (room, stay, hotel)  -1.025499
#
# [8071 rows x 2 columns]

# %%
stop_word_list = set(stopwords.words('english'))

# %%
# Filter for bigrams with only noun-type structures
def bigram_filter(bigram):
    tag = nltk.pos_tag(bigram)
    if tag[0][1] not in ['JJ', 'NN'] and tag[1][1] not in ['NN']:
        return False
    if bigram[0] in stop_word_list or bigram[1] in stop_word_list:
        return False
    if 'n' in bigram or 't' in bigram:
        return False
    if 'PRON' in bigram:
        return False
    return True

# %%
# Filter for trigrams with only noun-type structures
def trigram_filter(trigram):
    tag = nltk.pos_tag(trigram)
    if tag[0][1] not in ['JJ', 'NN'] and tag[1][1] not in ['JJ','NN']:
        return False
    if trigram[0] in stop_word_list or trigram[-1] in stop_word_list or trigram[1] in stop_word_list:
        return False
    if 'n' in trigram or 't' in trigram:
         return False
    if 'PRON' in trigram:
        return False
    return True

# %%
# Can set pmi threshold to whatever makes sense - eyeball through and select threshold where n-grams stop making sense
# choose top 500 ngrams in this case ranked by PMI that have noun like structures
filtered_bigram = bigram_pmi[bigram_pmi.apply(lambda bigram: bigram_filter(bigram['bigram']) and bigram.pmi > 5, axis = 1)][:500]

filtered_trigram = trigram_pmi[trigram_pmi.apply(lambda trigram: \
                                                 trigram_filter(trigram['trigram'])\
                                                 and trigram.pmi > 5, axis = 1)][:500]


bigrams = [' '.join(x) for x in filtered_bigram.bigram.values if len(x[0]) > 2 or len(x[1]) > 2]
trigrams = [' '.join(x) for x in filtered_trigram.trigram.values if len(x[0]) > 2 or len(x[1]) > 2 and len(x[2]) > 2]

# %%
bigrams[:15]
# Out:
# ['pina colada',
#  'laurent perrier',
#  'foie gras',
#  'sri lanka',
#  'giovanni viterale',
#  'origin bloom',
#  'kuala lumpur',
#  'hor oeuvre',
#  'tong yien',
#  'skating rink',
#  'roberto cavalli',
#  'louis vuitton',
#  'clifford pier',
#  'veuve cliquot',
#  'koh samui']

# %%
trigrams[:15]
# Out:
# ['din tai fung',
#  'ruth chris steak',
#  'mass rapid transit',
#  'scan qr code',
#  'yvonne yee ming',
#  'cut wolfgang puck',
#  'crazy rich asians',
#  'lau pa sit',
#  'est la vie',
#  'willow stream spa',
#  'lobster nasi lemak',
#  'hai tien lo',
#  'spago wolfgang puck',
#  'hai tien lou',
#  'shampoo conditioner body']

# %%
# Concatenate n-grams
def replace_ngram(x):
    for gram in trigrams:
        x = x.replace(gram, '_'.join(gram.split()))
    for gram in bigrams:
        x = x.replace(gram, '_'.join(gram.split()))
    return x

# %%
reviews_w_ngrams = reviews.copy()
final_reviews = reviews_w_ngrams.map(lambda x: replace_ngram(x))
final_reviews.head()
# Out:
# 0    excellent stay fantastic scenery th stay still...
# 1    pampercation th floor crest suite harbour view...
# 2    excellent location facility conference venue h...
# 3    great experience stay swissotel great staying ...
# 4    decent stay something improve decent stay swis...
# Name: lem_review, dtype: object

# %%
#final_reviews = final_reviews.apply(lambda x: [x])
final_review = final_reviews.tolist()
final_reviews = ""
for x in final_review:
    final_reviews += x

# %%
final_reviews = final_reviews.split()

# %%
x = []
for i in final_reviews:
    pos_comment = nltk.pos_tag([i])
    word = pos_comment[0]
    if word[1] == 'NN':
        x.append(word[0])
x
# Out:
# ['excellent',
#  'stay',
#  'scenery',
#  'th',
#  'stay',
#  'propose',
#  'wife',
#  'hotel',
#  'stay',
#  'hotel',
#  'time',
#  'way',
#  'staff',
#  'request',
#  'act',
#  'receive',
#  'complimentary',
#  'cake',
#  'check',
#  'weekend',
#  'stay',
#  'minor',
#  'comment',
#  'pillow',
#  'firm',
#  'pillow',
#  'thoughpampercation',
#  'th',
#  'floor',
#  'crest',
#  'suite',
#  'harbour',
#  'view',
#  'suite',
#  'spectacular',
#  'view',
#  'complimentary',
#  'minibar',
#  'access',
#  'executive',
#  'lounge',
#  'indulge',
#  'service',
#  'suite',
#  'meet',
#  'greet',
#  'hotel',
#  'escort',
#  'suite',
#  'check',
#  'touch',
#  'birthday',
#  'suite',
#  'mention',
#  'birthday',
#  'surprise',
#  'explore',
#  'option',
#  'breakfast',
#  'buffet',
#  'spread',
#  'pool',
#  'surround',
#  'area',
#  'capacity',
#  'hotel',
#  'share',
#  'pool',
#  'fairmont',
#  'room',
#  'service',
#  'experience',
#  'brilliant',
#  'food',
#  'serve',
#  'service',
#  'lady',
#  'sorry_forgot_name',
#  'personalityexcellent',
#  'location',
#  'facility',
#  'conference',
#  'venue',
#  'hotel',
#  'locate',
#  'marina',
#  'walk',
#  'morning',
#  'city',
#  'beautiful',
#  'landscape',
#  'hotel',
#  'number',
#  'meeting',
#  'room',
#  'vary',
#  'appropriate',
#  'hold',
#  'conference',
#  'seminar',
#  'business',
#  'meetinggreat',
#  'experience',
#  'stay',
#  'swissotel',
#  'watch',
#  'f',
#  'singapore',
#  'gp',
#  'view',
#  'location',
#  'convenient',
#  'aceess',
#  'toursit',
#  'area',
#  'connect',
#  'mrt',
#  'station',
#  'food',
#  'recommend',
#  'stay',
#  'plan',
#  'visitdecent',
#  'stay',
#  'something',
#  'decent',
#  'stay',
#  'swissotel_stamford',
#  'business',
#  'meeting',
#  'location',
#  'personalise',
#  'service',
#  'stay',
#  'customer',
#  'service',
#  'member',
#  'use',
#  'enjoy',
#  'welcome',
#  'drink',
#  'love',
#  'business',
#  'partner',
#  'complimentary',
#  'guest',
#  'pay',
#  'something',
#  'toilet',
#  'report',
#  'sharegreat',
#  'stay',
#  'location',
#  'convenient',
#  'food',
#  'shopping',
#  'walk',
#  'tourist',
#  'location',
#  'love',
#  'concept',
#  'self',
#  'check',
#  'room',
#  'view',
#  'balcony',
#  'breakfast',
#  'place',
#  'greatgreat',
#  'place',
#  'stay',
#  'room',
#  'clean',
#  'access',
#  'mrt',
#  'facility',
#  'staff',
#  'th',
#  'floor',
#  'helpful',
#  'smile',
#  'place',
#  'stay',
#  'singapore',
#  'timegreat',
#  'staff',
#  'excellent',
#  'stay',
#  'staff',
#  'hai',
#  'jiao',
#  'surprise',
#  'hotel',
#  'room',
#  'thank',
#  'view',
#  'th',
#  'floor',
#  'fitness',
#  'facility',
#  'tennis_court',
#  'hotelgreat',
#  'place',
#  'stay',
#  'room',
#  'access',
#  'everything',
#  'u',
#  'need',
#  'staff',
#  'helpful',
#  'issue',
#  'television',
#  'quick',
#  'send',
#  'tech',
#  'minute',
#  'call',
#  'pm',
#  'servicegood',
#  'hotel',
#  'singapore',
#  'hotel',
#  'singapore',
#  'bar',
#  'none',
#  'location',
#  'country',
#  'room',
#  'staff',
#  'cheap',
#  'afford',
#  'trip',
#  'easydisappoint',
#  'careful',
#  'charge',
#  'notify',
#  'mistake',
#  'pay',
#  'everything',
#  'advance',
#  'surprise',
#  'amount',
#  'experience',
#  'hotel',
#  'charge',
#  'hotel',
#  'experience',
#  'time',
#  'business',
#  'trip',
#  'room',
#  'clean',
#  'staff',
#  'right',
#  'city_hall_mrt',
#  'plenty',
#  'access',
#  'rest',
#  'city',
#  'cheary',
#  'th',
#  'floor',
#  'lounge',
#  'welcome',
#  'experience',
#  'aroundtop',
#  'cheary',
#  'multiple',
#  'business',
#  'trip',
#  'part',
#  'experience',
#  'th',
#  'nothing',
#  'conversation',
#  'thank',
#  'ton',
#  'chearyswisshotel',
#  'thank',
#  'rozannah',
#  'stay',
#  'hotel',
#  'super',
#  'bit',
#  'problem',
#  'room',
#  'rozannah',
#  'super',
#  'helpful',
#  'sort',
#  'room',
#  'praise',
#  'rozannah',
#  'staff',
#  'polite',
#  'welcome',
#  'place',
#  'alwaya',
#  'clean',
#  'comeroom',
#  'view',
#  'stay',
#  'night',
#  'f',
#  'location',
#  'hotel',
#  'clean',
#  'view',
#  'staff',
#  'efficient',
#  'housekeeper',
#  'conceige',
#  'super',
#  'quick',
#  'nd',
#  'floor',
#  'ask',
#  'room',
#  'eat',
#  'breakfast',
#  'visit',
#  'bar',
#  'th',
#  'floor',
#  'receive',
#  'service',
#  'recommend',
#  'stay',
#  'hope',
#  'returngreat',
#  'hospitality',
#  'hospitality',
#  'exceed_expectation',
#  'room',
#  'marina',
#  'bay',
#  'side',
#  'view',
#  'clean',
#  'hotel',
#  'offer',
#  'amenity',
#  'think',
#  'include',
#  'breakfast',
#  'stay',
#  'buffet',
#  'amazingbreathtake',
#  'view',
#  'direction',
#  'ask',
#  'business',
#  'trip',
#  'bed',
#  'linen',
#  'view',
#  'breathtaking',
#  'situate',
#  'shopping',
#  'mall',
#  'fact',
#  'situate',
#  'food',
#  'short_walking_distance',
#  'attraction',
#  'metrowonderful',
#  'view',
#  'room',
#  'location',
#  'mrt',
#  'city',
#  'hall',
#  'line',
#  'precise',
#  'raffle',
#  'city',
#  'mall',
#  'building',
#  'check',
#  'process',
#  'use',
#  'check',
#  'machine',
#  'want',
#  'fast',
#  'check',
#  'email',
#  'link',
#  'check',
#  'need',
#  'photo',
#  'passport',
#  'photo',
#  'credit',
#  'card',
#  'deposit',
#  'sgd',
#  'step',
#  'check',
#  'machine',
#  'hotel',
#  'check',
#  'enter',
#  'book',
#  'code',
#  'card',
#  'right',
#  'fast',
#  'lobby',
#  'twg',
#  'tenant',
#  'lobby',
#  'room',
#  'divide',
#  'zone',
#  'lift',
#  'zone',
#  'lift',
#  'serve',
#  'floor',
#  'zone',
#  'lift',
#  'serve',
#  'floor',
#  'room',
#  'view',
#  'room',
#  'andaz',
#  'hotel',
#  'building',
#  'jw',
#  'marriot',
#  'pan',
#  'pacific',
#  'suntec',
#  'city',
#  'singapore',
#  'flyer',
#  'marina',
#  'baysand',
#  'marina',
#  'bay',
#  'harbour',
#  'room',
#  'measure',
#  'x',
#  'mattress',
#  'type',
#  'pillow',
#  'singapore',
#  'room',
#  'size',
#  'room',
#  'floor',
#  'carpet',
#  'sofa',
#  'bed',
#  'equip',
#  'chair',
#  'balcony',
#  'view',
#  'singapore',
#  'tea',
#  'use',
#  'twg',
#  'brand',
#  'breakfast',
#  'chamomile',
#  'jasmine',
#  'earl',
#  'gray',
#  'coffee',
#  'use',
#  'nespresso',
#  'capsule',
#  'type',
#  'arpeggio',
#  'lungo',
#  'decaffeinate',
#  'cupboard',
#  'laundry',
#  'bag',
#  'bathrobe',
#  'hotel',
#  'slipper',
#  'iron',
#  'hairdyer',
#  'look',
#  'anniversary',
#  'box',
#  'chocolate',
#  'cake',
#  'standard',
#  'bathroom',
#  'closet',
#  'sink',
#  'shower',
#  'amenity',
#  'provide',
#  'use',
#  'purovel',
#  'brand',
#  'masculine',
#  'mint',
#  'aroma',
#  'toothbrushe',
#  'complementary',
#  'amenity',
#  'provide',
#  'request',
#  'shaving_kit',
#  'body',
#  'towel',
#  'hand',
#  'towel',
#  'face',
#  'towel',
#  'provide',
#  'swissotel',
#  'singapore',
#  'mineral',
#  'water',
#  'provide',
#  'bathroom',
#  'tap',
#  'drinking',
#  'water',
#  'drink',
#  'water',
#  'tap',
#  'tap',
#  'water',
#  'filter',
#  'carbon',
#  'filter',
#  'hotel',
#  'facility',
#  'swissotel',
#  'fairmont',
#  'singapore',
#  'building',
#  'facility',
#  'cluster',
#  'facility',
#  'swissotel',
#  'fairmont',
#  'restaurant',
#  'pool',
#  'pool',
#  'adult',
#  'pool',
#  'child',
#  'pool',
#  'gym',
#  'consist',
#  'floor',
#  'weight',
#  'cardio',
#  'jacuzzi',
#  'sauna',
#  'use',
#  'camera',
#  'prohibit',
#  'wear',
#  'appropriate',
#  'clothing',
#  'swimwear',
#  'enter',
#  'gym',
#  'photo',
#  'guest',
#  'order',
#  'receptionist',
#  'tennis_court',
#  'restaurant',
#  'clove',
#  'use',
#  'breakfast',
#  'try',
#  'breakfast',
#  'roomgreat',
#  'hotel',
#  'location',
#  'kudo',
#  'hotel',
#  'sustainability',
#  'effort',
#  'hotel',
#  'locate',
#  'everything',
#  'staff',
#  'room',
#  'light',
#  'breakfast',
#  'food',
#  'selection',
#  'variety',
#  'limitedgreat',
#  'view',
#  'view',
#  'marina',
#  'bay',
#  'comfy',
#  'spotless',
#  'clean',
#  'room',
#  'choice',
#  'restaurant',
#  'facility',
#  'breakfast',
#  'clove',
#  'excellent',
#  'lobby',
#  'design',
#  'flower',
#  'stay',
#  'nd',
#  'home',
#  'home_away_home',
#  'hotel',
#  'mrt',
#  'station',
#  'shopping',
#  'mall',
#  'restaurant',
#  'hotel',
#  'exploration',
#  'singapore',
#  'view',
#  'sea',
#  'side',
#  'stay',
#  'singapore',
#  'stay',
#  'weekend',
#  'suite',
#  'upgrade',
#  'room',
#  'level',
#  'harbour',
#  'suite',
#  'view',
#  'awesome',
#  'position',
#  'everything',
#  'raffle',
#  'beautiful',
#  'shopping',
#  'mall',
#  'part',
#  'fault',
#  'service',
#  'breakfast',
#  'buffet',
#  'stay_anywhere_else',
#  'singaporegreat',
#  'stay',
#  'location',
#  'hotel',
#  'location',
#  'nothing',
#  'perfect',
#  'heart',
#  'city',
#  'provide',
#  'access',
#  'major_tourist_attraction',
#  'want',
#  'explore',
#  'historic',
#  'landmark',
#  'indulge',
#  'retail_therapy',
#  'savor',
#  'cuisine',
#  'everything',
#  'stone_throw_away',
#  'adventure',
#  'convenient',
#  'stress',
#  'fast',
#  'check',
#  'check',
#  'hotel',
#  'journey',
#  'delight',
#  'user',
#  'kiosk',
#  'wait',
#  'tap',
#  'screen',
#  'room',
#  'key',
#  'hand',
#  'start',
#  'stay',
#  'matter',
#  'minute',
#  'efficiency',
#  'extend',
#  'self',
#  'checkout',
#  'kiosk',
#  'time',
#  'depart',
#  'conveniencegreat',
#  'stay',
#  'hotel',
#  'breakfast',
#  'service',
#  'locate',
#  'shopping',
#  'mall',
#  'clean',
#  'location',
#  'thank',
#  'fang',
#  'cute',
#  'towel_animal',
#  'clean',
#  'room',
#  'recommend',
#  'business',
#  'pleasurefavorite',
#  'hotel',
#  'super',
#  'location',
#  'room',
#  'king',
#  'bed',
#  'service',
#  'ok',
#  'breakfast',
#  'buffet',
#  'fast',
#  'elevator',
#  'fridge',
#  'room',
#  'walk',
#  'distance',
#  'mile',
#  'bay',
#  'lot',
#  'stuff',
#  'include',
#  'hub',
#  'metro',
#  'stop',
#  'right',
#  'build',
#  'shopping',
#  'mall',
#  'right',
#  'hotel',
#  'room',
#  'comfy',
#  'bery',
#  'clean',
#  'amenity',
#  'lounge',
#  'awesome',
#  'staff',
#  'compare',
#  'premier',
#  'lounge',
#  'staff',
#  'sofitel',
#  'pullman',
#  'staf',
#  'attentivegreat',
#  'location',
#  'staff',
#  'book',
#  'accomodation',
#  'singapore',
#  'choice',
#  'base',
#  'price',
#  'photo',
#  'room',
#  'realise',
#  'location',
#  'hotel',
#  'walk',
#  'distance',
#  'marina_bay_sand',
#  'attraction',
#  'access',
#  'transport',
#  'simple',
#  'mrt',
#  'station',
#  'right',
#  'hotel',
#  'underground',
#  'mall',
#  'link',
#  'hotel',
#  'station',
#  'shopping',
#  'centre',
#  'wet',
#  'day',
#  'hotel',
#  'staff',
#  'stay',
#  'room',
#  'upgrade',
#  'touch',
#  'stay',
#  'honeymoon',
#  'staff',
#  'pleasure',
#  'speak',
#  'feel',
#  'welcome',
#  'recommend',
#  'plan',
#  'stay',
#  'singapore',
#  'tripnever',
#  'time',
#  'experience',
#  'time',
#  'room',
#  'need',
#  'maintenance',
#  'express',
#  'check',
#  'check',
#  'seem',
#  'provide',
#  'convenience',
#  'request',
#  'reception',
#  'support',
#  'contact',
#  'point',
#  'change',
#  'invoice',
#  'worth',
#  'money',
#  'think',
#  'comegreat',
#  'hotel',
#  'singapore',
#  'hotel',
#  'right',
#  'singapore',
#  'gran',
#  'prix',
#  'track',
#  'hotel',
#  'view',
#  'marina',
#  'bay',
#  'room',
#  'shopping',
#  'mall',
#  'access',
#  'hotel',
#  'foyer',
#  'st',
#  'nd',
#  'place',
#  'visit',
#  'staff',
#  'welcome',
#  'hotel',
#  'stay',
#  'provide',
#  'balcony',
#  'raffle',
#  'rear',
#  'hotel',
#  'walk',
#  'sim',
#  'lim',
#  'square',
#  'place',
#  'computer',
#  'stay',
#  'place',
#  'th',
#  'level',
#  'room',
#  'wonderful',
#  'panoramic',
#  'view',
#  'city',
#  'sea',
#  'clean',
#  'food',
#  'drink',
#  'serve',
#  'club',
#  'floor',
#  'forget',
#  'staff',
#  'serviceanother',
#  'trip',
#  'stay',
#  'night',
#  'th',
#  'august',
#  'stay',
#  'staff',
#  'rhea',
#  'staff',
#  'club',
#  'lounge',
#  'look',
#  'feel',
#  'spoil',
#  'hotel',
#  'mrt',
#  'shopping',
#  'centre',
#  'thankyou',
#  'hotel',
#  'staff',
#  'stay',
#  'anne',
#  'hotel',
#  'provide',
#  'service',
#  'night',
#  'staff',
#  'bother',
#  'turn',
#  'bed',
#  'etc',
#  'night',
#  'morning',
#  'hotel',
#  'standardroom',
#  'view',
#  'hotel',
#  'location',
#  'access',
#  'shopping',
#  'transport',
#  'etc',
#  'upgrade',
#  'room',
#  'view',
#  'boy',
#  'view',
#  'staff',
#  'super',
#  'helpful',
#  'stay',
#  'singapore',
#  'doubt',
#  'breakfast',
#  'variety',
#  'excellent',
#  'delicioustwin',
#  'bed',
#  'room',
#  'fit',
#  'family',
#  'love',
#  'hotel',
#  'twin',
#  'bed',
#  'family',
#  'point',
#  'family',
#  'welcome',
#  'fruit',
#  'room',
#  'check',
#  'chocolate',
#  'cake',
#  'everyday',
#  'view',
#  'room',
#  'love',
#  'visit',
#  'singaporespectacular',
#  'view',
#  'spectacular',
#  'view',
#  'helpful',
#  'staff',
#  'room',
#  'property',
#  'toilet',
#  'bidet',
#  'family',
#  'wonderful',
#  'stay',
#  'love',
#  'marina',
#  'bay',
#  'view',
#  'beautifulgreat',
#  'room',
#  ...]

# %%
final_reviews = x

# %%
dictionary = corpora.Dictionary([final_reviews])

# %%
doc_term_matrix = [dictionary.doc2bow([doc]) for doc in final_reviews]

# %%
'''
coherence = []
for k in range(3,11):
    print('Round: '+str(k))
    Lda = gensim.models.ldamodel.LdaModel
    ldamodel = Lda(doc_term_matrix, num_topics=k, id2word = dictionary, passes=40,\
                   iterations=200, chunksize = 10000, eval_every = None)
    
    cm = gensim.models.coherencemodel.CoherenceModel(model=ldamodel, texts=final_reviews,\
                                                     dictionary=dictionary, coherence='c_v')
    coherence.append((k,cm.get_coherence()))
'''
# Out:
# "\ncoherence = []\nfor k in range(3,11):\n    print('Round: '+str(k))\n    Lda = gensim.models.ldamodel.LdaModel\n    ldamodel = Lda(doc_term_matrix, num_topics=k, id2word = dictionary, passes=40,                   iterations=200, chunksize = 10000, eval_every = None)\n    \n    cm = gensim.models.coherencemodel.CoherenceModel(model=ldamodel, texts=final_reviews,                                                     dictionary=dictionary, coherence='c_v')\n    coherence.append((k,cm.get_coherence()))\n"

# %%
'''
x_val = [x[0] for x in coherence]
y_val = [x[1] for x in coherence]
'''
# Out:
# '\nx_val = [x[0] for x in coherence]\ny_val = [x[1] for x in coherence]\n'

# %%
'''
plt.plot(x_val,y_val)
plt.scatter(x_val,y_val)
plt.title('Number of Topics vs. Coherence')
plt.xlabel('Number of Topics')
plt.ylabel('Coherence')
plt.xticks(x_val)
plt.show()
'''
# Out:
# "\nplt.plot(x_val,y_val)\nplt.scatter(x_val,y_val)\nplt.title('Number of Topics vs. Coherence')\nplt.xlabel('Number of Topics')\nplt.ylabel('Coherence')\nplt.xticks(x_val)\nplt.show()\n"

# %%
Lda = gensim.models.ldamodel.LdaModel
ldamodel = Lda(doc_term_matrix, num_topics=5, id2word = dictionary, passes=40,\
               iterations=200,  chunksize = 10000, eval_every = None, random_state=0)

# %%
ldamodel.show_topics(5, num_words=10, formatted=False)
# Out:
# [(0,
#   [('room', 0.17086901),
#    ('thank', 0.02778849),
#    ('enjoy', 0.025550712),
#    ('helpful', 0.021703754),
#    ('buffet', 0.02161855),
#    ('walk', 0.020139378),
#    ('birthday', 0.019792272),
#    ('visit', 0.019477786),
#    ('everything', 0.014582665),
#    ('star', 0.01430211)]),
#  (1,
#   [('stay', 0.12050929),
#    ('view', 0.05989773),
#    ('food', 0.054466013),
#    ('excellent', 0.040791284),
#    ('pool', 0.031735215),
#    ('marina', 0.031172885),
#    ('day', 0.029853014),
#    ('place', 0.029173449),
#    ('feel', 0.019838797),
#    ('staycation', 0.013645659)]),
#  (2,
#   [('hotel', 0.2069512),
#    ('service', 0.09985726),
#    ('singapore', 0.062973276),
#    ('breakfast', 0.04648913),
#    ('location', 0.04638615),
#    ('beautiful', 0.021788752),
#    ('afternoon', 0.01906578),
#    ('area', 0.018283708),
#    ('bed', 0.01582549),
#    ('building', 0.014789774)]),
#  (3,
#   [('fullerton', 0.07440514),
#    ('time', 0.041130897),
#    ('experience', 0.035579357),
#    ('bay', 0.029889552),
#    ('club', 0.027151763),
#    ('recommend', 0.022366596),
#    ('wonderful', 0.022322703),
#    ('love', 0.019616777),
#    ('book', 0.019456143),
#    ('look', 0.018994542)]),
#  (4,
#   [('staff', 0.09009609),
#    ('tea', 0.03897438),
#    ('check', 0.037288975),
#    ('night', 0.037179757),
#    ('restaurant', 0.033944104),
#    ('clean', 0.017297283),
#    ('floor', 0.016472232),
#    ('river', 0.014142778),
#    ('bathroom', 0.013187315),
#    ('team', 0.012690993)])]

# %%
topic_data =  pyLDAvis.gensim.prepare(ldamodel, doc_term_matrix, dictionary, mds = 'pcoa')
pyLDAvis.display(topic_data)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el93348140261222492864688686593" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el93348140261222492864688686593_data = {"mdsDat": {"x": [-0.09154173730488742, 0.4205127930016144, -0.13317289460025364, -0.06630375123137085, -0.12949440986510283], "y": [0.0456468891147886, -0.008256802328333195, -0.3606520358464902, 0.023456414931315662, 0.29980553412871924], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [20.47801086400986, 20.066200061678366, 19.921530648732755, 19.784766410650303, 19.749492014928713]}, "tinfo": {"Term": ["hotel", "room", "stay", "service", "staff", "fullerton", "singapore", "view", "food", "breakfast", "location", "excellent", "time", "tea", "check", "night", "experience", "restaurant", "pool", "marina", "day", "bay", "place", "thank", "club", "enjoy", "recommend", "wonderful", "beautiful", "helpful", "stay", "view", "food", "excellent", "pool", "marina", "day", "place", "feel", "staycation", "serve", "top", "lounge", "try", "help", "access", "hour", "show", "ambience", "mandarin", "choose", "eat", "relax", "water", "luxury", "coffee", "start", "efficient", "world", "husband", "hotel", "service", "singapore", "breakfast", "location", "beautiful", "afternoon", "area", "bed", "building", "provide", "guest", "family", "drink", "city", "way", "lobby", "year", "front", "worth", "wait", "bit", "reception", "thing", "history", "standard", "tour", "set", "smile", "kind", "staff", "tea", "check", "night", "restaurant", "clean", "floor", "river", "bathroom", "team", "business", "offer", "balcony", "courtyard", "lot", "lalikumar", "cake", "friend", "include", "trip", "heritage", "selection", "spend", "call", "light", "sure", "superb", "face", "minute", "concierge", "room", "thank", "enjoy", "helpful", "buffet", "walk", "birthday", "visit", "everything", "star", "dinner", "want", "perfect", "welcome", "choice", "strait", "ask", "upgrade", "work", "return", "suite", "request", "pleasant", "overlook", "pm", "desk", "amenity", "warm", "celebration", "surprise", "fullerton", "time", "experience", "bay", "club", "recommend", "wonderful", "love", "book", "look", "bar", "need", "use", "town", "th", "quality", "locate", "facility", "right", "price", "wedding", "level", "think", "manager", "tell", "shower", "celebrate", "care", "table", "variety"], "Freq": [54635.0, 44477.0, 32468.0, 26363.0, 23614.0, 19333.0, 16625.0, 16138.0, 14674.0, 12273.0, 12246.0, 10990.0, 10687.0, 10215.0, 9774.0, 9745.0, 9245.0, 8897.0, 8550.0, 8399.0, 8043.0, 7767.0, 7860.0, 7234.0, 7055.0, 6651.0, 5812.0, 5800.0, 5753.0, 5650.0, 32467.26324749385, 16137.472258885646, 14674.075246846463, 10989.869528550491, 8550.00969078133, 8398.508182090833, 8042.912538984741, 7859.825947346041, 5344.91114038428, 3676.3739325153692, 3578.632553450177, 3304.137156018026, 3110.677770217594, 2944.635531133617, 2696.8439312693527, 2553.9658427469835, 2237.060420767078, 2225.577331148993, 2145.322415507246, 1975.2075875979408, 1962.4232567964318, 1952.7550297853086, 1818.8895293978026, 1706.8648579364674, 1687.2162666153047, 1623.7100011112616, 1587.4008305462216, 1498.332176294846, 1406.531944306613, 1398.2920465351042, 54634.94085552898, 26362.23248392619, 16624.891190589828, 12273.090925385348, 12245.90378486144, 5752.211899546285, 5033.349836573277, 4826.883350788767, 4177.915763647532, 3904.4877657784414, 3586.7193749094004, 3514.290242084599, 3440.3849155857133, 3319.736324538439, 3084.2308176915135, 3061.7850027523896, 2634.2973614757134, 2469.2171602644175, 2437.2557477945793, 2404.6774515925167, 2174.2469137040807, 2160.1677534177575, 2148.7717546179897, 2145.7763403056365, 1812.5827827763924, 1746.3163405646692, 1628.240147304721, 1605.8660029945106, 1584.6067487934167, 1490.6024209162224, 23613.809428847806, 10215.021571424344, 9773.284417248684, 9744.658820159855, 8896.607687413376, 4533.545497825132, 4317.303023438948, 3706.7629161867067, 3456.3402017674844, 3326.2562051461878, 3180.4641586591065, 3047.7461247724304, 2914.7720344413674, 2832.280607166499, 2716.3009513169695, 2740.5594312975695, 2598.807657706100 ...
